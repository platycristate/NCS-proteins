# %%
import hpca_session
from neuron import h, gui
from neuron.units import ms, mV
import matplotlib.pyplot as plt
from matplotlib import style
from matplotlib import style, rc
import numpy as np
import pickle
h.load_file("stdrun.hoc");
style.use("seaborn")
from jupyterthemes import jtplot
jtplot.style()
# %matplotlib notebook
h.k8HPCA_hpca = 7.5e-5

# %%
t = h.Vector().record(h._ref_t)
v = h.Vector().record(h.dend11[10](0.5)._ref_v)

# %%
# Current pulses generator object at the center of the soma
ipulses = h.Ipulse2(h.soma(0.5))
ipulses.amp = 5 # nA
ipulses.dur = 1 # ms
ipulses.per = 20 # ms
ipulses.num = 50
ipulses.delay = 4000 # ms

# %%
h.k8HPCA_hpca = 0.002
h.finitialize();
h.continuerun(10000 * ms);
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-16fa66abfd97> in <module>
# ----> 1 h.k8HPCA_hpca = 0.002
#       2 h.finitialize();
#       3 h.continuerun(10000 * ms);
#
# TypeError: not assignable

# %%
plt.figure(figsize=(9, 6))
plt.plot(t, v)
plt.title('Apical dendrite')
plt.xlabel('time [ms]')
plt.ylabel('v [mV]')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="899.3">

# %%
with open('Results/subthresh/subthresh_response_ipulses.p', 'wb') as f:
    pickle.dump({t: 't', v: 'dend_v'}, f)

# %%
ipulses.amp = 3
h.finitialize();
h.continuerun(10000 * ms);

# %%
plt.figure(figsize=(9, 6))
plt.plot(t, v)
plt.title('Apical dendrite')
plt.xlabel('time [ms]')
plt.ylabel('v [mV]')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="899.3">

# %%
with open('Results/subthresh/subthresh_response_ipulses_3nA.p', 'wb') as f:
    pickle.dump({t: 't', v: 'dend_v'}, f)
